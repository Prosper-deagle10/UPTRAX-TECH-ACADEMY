# %% [markdown]
# ## INTRODUCTION TO PYTHON

# %%
# this is python comment 
print('Data analysis') # this will return the string
# Out:
# Data analysis

# %%
b = 20

# %%
print(b)
# Out:
# 20

# %%
b
# Out:
# 20

# %%
6
# Out:
# 6

# %%
True - 4
# Out:
# -3

# %%
type(4)
# Out:
# int

# %%
type(0)
# Out:
# int

# %%
c = int(input("Give me a number: "))
print(f"the number you gave is {c}")
# Out:
# Give me a number: 9.34
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 c = int(input("Give me a number: "))
#       2 print(f"the number you gave is {c}")
#
# ValueError: invalid literal for int() with base 10: '9.34'

# %%
input("your name")
# Out:
# your nameprosper
# 'prosper'

# %%
# floating values -- decimals 
print(type(2.0))
# Out:
# <class 'float'>

# %%
type(3.5)
# Out:
# float

# %%
# complex -- vector 
type(2 + 3j)
# Out:
# complex

# %%
# string 
type('prosper')
# Out:
# str

# %%
type("""prosper""")
# Out:
# str

# %%
type("tech")
# Out:
# str

# %%
type('''gggggg''')
# Out:
# str

# %%
# operators 
2 + 2
# Out:
# 4

# %%
4*2
# Out:
# 8

# %%
4^2
# Out:
# 6

# %%
4**2
# Out:
# 16

# %%
7/2
# Out:
# 3.5

# %%
7//2
# Out:
# 3

# %%
2 < 4
# Out:
# True

# %%
## variables & datatypes

# %%
# Hashtag is used for making a comment

# This is a comment 

# INT, float, complex, strings

# List n the tuple.

# %%
numbers = [2,3,4,5.5,6,7,'fruit']
type(numbers)
# Out:
# list

# %%
print(type(numbers))
# Out:
# <class 'list'>

# %%
type([2,3,4])
# Out:
# list

# %%
fruits = ['mango', 'orange', 'apple']
print(fruits)
# Out:
# ['mango', 'orange', 'apple']

# %%
print(type(fruits))
# Out:
# <class 'list'>

# %%
fruits.append('pineapple')

# %%
fruits
# Out:
# ['mango', 'orange', 'apple', 'pineapple']

# %%
fruits.remove('orange')

# %%
fruits
# Out:
# ['mango', 'apple', 'pineapple']

# %%
# [] bracket, () parenthesis, {} braces

# %%
a = [2,3,4,5,6]
type(a)
# Out:
# list

# %%
print(type(a))
# Out:
# <class 'list'>

# %%
fruits = ['mango', 'apple', 'cucumber',2,3.5]
print(fruits)
# Out:
# ['mango', 'apple', 'cucumber', 2, 3.5]

# %%
type(fruits)
# Out:
# list

# %%
# immutable
fruits
# Out:
# ['mango', 'apple', 'cucumber', 2, 3.5]

# %%
fruits.remove(3.5)
print(fruits)
# Out:
# ['mango', 'apple', 'cucumber', 2]

# %%
fruits.remove(2)
print(fruits)
# Out:
# ['mango', 'apple', 'cucumber']

# %%
# append 
fruits.append('pineapple')
print(fruits)
# Out:
# ['mango', 'apple', 'cucumber', 'pineapple']

# %%
fruits.append('orange')
print(fruits)
# Out:
# ['mango', 'apple', 'cucumber', 'pineapple', 'orange']

# %%
fruits
# Out:
# ['mango', 'apple', 'cucumber', 'pineapple', 'orange']

# %%
# Indexing 0--9
for numbers in range(5):
    print(numbers)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
fruits
# Out:
# ['mango', 'apple', 'cucumber', 'pineapple', 'orange']

# %%
fruits[2:]
# Out:
# ['cucumber', 'pineapple', 'orange']

# %%
animals = ['goat', 'dog', 'cat']
print(animals[0])
# Out:
# goat

# %%
# TUPLE -- ()
animals = ('goat', 'dog', 'cat')
print(type(animals))
# Out:
# <class 'tuple'>

# %%
x = ['goat', 'dog', 'cat', 'cat', 'cat', 'dog']
print(x)
print(type(x))
# Out:
# ['goat', 'dog', 'cat', 'cat', 'cat', 'dog']
# <class 'list'>

# %%
x[2]
# Out:
# 'cat'

# %%
# SET {}
my_set = {2,3,4,5,6,7,8,9}
print(type(my_set))
# Out:
# <class 'set'>

# %%
y = {2,2,2,2,2,3,4,5,6,6,6,6,}
print(y)
# Out:
# {2, 3, 4, 5, 6}

# %%
books = {'a', 'b', 'c', 'd','d', 'd'}
print(books)
# Out:
# {'a', 'b', 'd', 'c'}

# %%
books.add('a')
print(books)
# Out:
# {'d', 'c', 'e', 'a', 'b'}

# %%
books.remove('a')
print(books)
# Out:
# {'d', 'c', 'e', 'b'}

# %%
books
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
# Boolean True & False
a = True # one 
b = False # 0
print(type(a))
# Out:
# <class 'bool'>

# %%
True - False + True
# Out:
# 2

# %%
# PYTHON 
# numpy, pandas
