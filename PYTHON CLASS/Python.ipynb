# %% [markdown]
# ## INTRODUCTION TO PYTHON

# %%
# this is python comment 
print('Data analysis') # this will return the string
# Out:
# Data analysis

# %%
b = 20

# %%
print(b)
# Out:
# 20

# %%
b
# Out:
# 20

# %%
6
# Out:
# 6

# %%
True - 4
# Out:
# -3

# %%
type(4)
# Out:
# int

# %%
type(0)
# Out:
# int

# %%
c = int(input("Give me a number: "))
print(f"the number you gave is {c}")
# Out:
# Give me a number: 9.34
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 c = int(input("Give me a number: "))
#       2 print(f"the number you gave is {c}")
#
# ValueError: invalid literal for int() with base 10: '9.34'

# %%
input("your name")
# Out:
# your nameprosper
# 'prosper'

# %%
# floating values -- decimals 
print(type(2.0))
# Out:
# <class 'float'>

# %%
type(3.5)
# Out:
# float

# %%
# complex -- vector 
type(2 + 3j)
# Out:
# complex

# %%
# string 
type('prosper')
# Out:
# str

# %%
type("""prosper""")
# Out:
# str

# %%
type("tech")
# Out:
# str

# %%
type('''gggggg''')
# Out:
# str

# %%
# operators 
2 + 2
# Out:
# 4

# %%
4*2
# Out:
# 8

# %%
4^2
# Out:
# 6

# %%
4**2
# Out:
# 16

# %%
7/2
# Out:
# 3.5

# %%
7//2
# Out:
# 3

# %%
2 < 4
# Out:
# True

# %%
## variables & datatypes
